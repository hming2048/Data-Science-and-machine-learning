# %% [markdown]
# ___
# # Plotly and Cufflinks

# %% [markdown]
# Plotly is a library that allows you to create interactive plots that you can use in dashboards or websites (you can save them as html files or static images).
#
# ## Installation
#
# In order for this all to work, you'll need to install plotly and cufflinks to call plots directly off of a pandas dataframe. These libraries are not currently available through **conda** but are available through **pip**. Install the libraries at your command line/terminal using:
#
#     pip install plotly
#     pip install cufflinks
#
# ** NOTE: Make sure you only have one installation of Python on your computer when you do this, otherwise the installation may not work. **
#
# ## Imports and Set-up

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

print(__version__) # requires version >= 1.9.0
# Out:
# 3.10.0

# %%
import cufflinks as cf

# %%
# For Notebooks
init_notebook_mode(connected=True) # connect javascript
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# For offline use
cf.go_offline()# off line
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Fake Data

# %%
df = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())

# %%
pd.DataFrame(np.random.rand(100,4)).head(3)
# Out:
#           0         1         2         3
# 0  0.654406  0.628082  0.530787  0.578572
# 1  0.262435  0.584109  0.682381  0.096983
# 2  0.849231  0.194889  0.281893  0.918734

# %%
df.head()
# Out:
#           A         B         C         D
# 0  0.140818 -1.632147 -0.847028 -1.085462
# 1 -2.000435 -1.712173 -1.541002 -0.387884
# 2 -0.250241  0.117979  0.668573 -0.025683
# 3  1.120142 -1.810628  0.692499 -2.278369
# 4  1.089179  0.881644  0.068952  0.743860

# %%
df2 = pd.DataFrame({'Category':['A','B','C'],'Values':[32,43,50]})

# %%
df2.head()
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
df.plot()

# %%
df.iplot() #itertiva and zoom in  other information move around
# Out:
# <div>
#
#
#             <div id="72bfff3e-90f0-4cc4-bc42-67305912b9c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("72bfff3e-90f0-4cc4-bc42-67305912b9c3")) {
#                     Plotly.newPlot(
#                         '72bfff3e-90f0-4cc4-bc42-67305912b9c3',
# ...

# %% [markdown]
# ## Using Cufflinks and iplot()
#
# * scatter
# * bar
# * box
# * spread
# * ratio
# * heatmap
# * surface
# * histogram
# * bubble

# %% [markdown]
# ## Scatter

# %%
df.iplot(kind='scatter',x='A',y='B',mode='markers',size=15)
# Out:
# <div>
#
#
#             <div id="fae18ea8-264b-4bd0-a1d3-5ff03dcd6806" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("fae18ea8-264b-4bd0-a1d3-5ff03dcd6806")) {
#                     Plotly.newPlot(
#                         'fae18ea8-264b-4bd0-a1d3-5ff03dcd6806',
# ...

# %% [markdown]
# ## Bar Plots

# %%
df2.iplot(kind='bar',x='Category',y='Values')
# Out:
# <div>
#
#
#             <div id="e68b479d-a7e7-434c-9ac7-f6838f82e36e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e68b479d-a7e7-434c-9ac7-f6838f82e36e")) {
#                     Plotly.newPlot(
#                         'e68b479d-a7e7-434c-9ac7-f6838f82e36e',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Values", "orientation": "v", "text": "", "type": "bar", "uid": "36272df7-8229-4140-976b-f264bb6e33a0", "x": ["A", "B", "C"], "y": [32, 43, 50]}],
# ...

# %%
df.count().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="63f771bf-9818-4b61-a181-5e750e73caae" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("63f771bf-9818-4b61-a181-5e750e73caae")) {
#                     Plotly.newPlot(
#                         '63f771bf-9818-4b61-a181-5e750e73caae',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "uid": "486b45c5-8985-4f95-914e-4802e243af41", "x": ["A", "B", "C", "D"], "y": [100, 100, 100, 100]}],
# ...

# %%
df.sum().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="580e3615-7898-4e66-b393-eeb86855724d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("580e3615-7898-4e66-b393-eeb86855724d")) {
#                     Plotly.newPlot(
#                         '580e3615-7898-4e66-b393-eeb86855724d',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "uid": "679fbc26-bffe-49a3-a0d1-fce068b43009", "x": ["A", "B", "C", "D"], "y": [15.093176634406122, 9.22958319062783, 3.5806994688412073, 1.9418671039175956]}],
# ...

# %% [markdown]
# ## Boxplots

# %%
df.iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="77dcd2f6-d853-4170-9e5e-cd23981e010b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("77dcd2f6-d853-4170-9e5e-cd23981e010b")) {
#                     Plotly.newPlot(
#                         '77dcd2f6-d853-4170-9e5e-cd23981e010b',
# ...

# %% [markdown]
# ## 3d Surface

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[500,400,300,200,100]})
df3
# Out:
#    x   y    z
# 0  1  10  500
# 1  2  20  400
# 2  3  30  300
# 3  4  20  200
# 4  5  10  100

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]})
df3.iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="76297a63-a745-42bc-8845-4afb1eea2ab4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("76297a63-a745-42bc-8845-4afb1eea2ab4")) {
#                     Plotly.newPlot(
#                         '76297a63-a745-42bc-8845-4afb1eea2ab4',
# ...

# %% [markdown]
# ## Spread

# %%
df[['A','B']]
# Out:
#            A         B
# 0   0.140818 -1.632147
# 1  -2.000435 -1.712173
# 2  -0.250241  0.117979
# 3   1.120142 -1.810628
# 4   1.089179  0.881644
# ..       ...       ...
# 95  2.131257 -0.506038
# 96  1.412713  0.430347
# 97  1.170606  1.086120
# 98 -0.814099 -0.773568
# 99 -0.449228  0.424863
#
# [100 rows x 2 columns]

# %%
df[['A','B']].iplot(kind='spread')
# Out:
# /Users/haiming/anaconda3/envs/ds/lib/python3.7/site-packages/cufflinks/plotlytools.py:847: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#
# /Users/haiming/anaconda3/envs/ds/lib/python3.7/site-packages/cufflinks/plotlytools.py:848: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
# <div>
#
#
#             <div id="a2f95f79-470e-47b4-b3de-59fce6a5d64e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a2f95f79-470e-47b4-b3de-59fce6a5d64e")) {
#                     Plotly.newPlot(
# ...

# %% [markdown]
# ## histogram

# %%
df['A'].iplot(kind='hist',bins=25)
# Out:
# <div>
#
#
#             <div id="8ee55e92-0cfd-4837-89e1-0fd9361f07b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8ee55e92-0cfd-4837-89e1-0fd9361f07b9")) {
#                     Plotly.newPlot(
#                         '8ee55e92-0cfd-4837-89e1-0fd9361f07b9',
# ...

# %%
df.iplot(kind='hist')
# Out:
# <div>
#
#
#             <div id="89110c30-7fa0-4ee7-ac38-549ba337d3a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("89110c30-7fa0-4ee7-ac38-549ba337d3a8")) {
#                     Plotly.newPlot(
#                         '89110c30-7fa0-4ee7-ac38-549ba337d3a8',
# ...

# %%
df.iplot(kind='bubble',x='A',y='B',size='C')
# Out:
# <div>
#
#
#             <div id="92d1c80e-55b3-4ec0-889d-b8355e93e0fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("92d1c80e-55b3-4ec0-889d-b8355e93e0fc")) {
#                     Plotly.newPlot(
#                         '92d1c80e-55b3-4ec0-889d-b8355e93e0fc',
# ...

# %% [markdown]
# ## scatter_matrix()
#
# Similar to sns.pairplot()

# %%
df.scatter_matrix() # same like seaborn plots
# Out:
# <div>
#
#
#             <div id="5a50e78b-099e-4e7b-93f6-e6da0355360f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5a50e78b-099e-4e7b-93f6-e6da0355360f")) {
#                     Plotly.newPlot(
#                         '5a50e78b-099e-4e7b-93f6-e6da0355360f',
# ...
